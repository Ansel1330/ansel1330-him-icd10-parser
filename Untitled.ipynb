# %%
pip install streamlit PyPDF2 Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cd C:\Users\ADMIN\Desktop\PROGRAMMING
streamlit run app.py
# Out:
#   Cell In[5], line 1
#     cd C:\Users\ADMIN\Desktop\PROGRAMMING
#        ^
# SyntaxError: invalid syntax
